# %%
import importlib
import src.ingestion.normalize
importlib.reload(src.ingestion.normalize)
from src.ingestion.normalize import normalize_dataset

# %%
rows = normalize_dataset(
    chapters_dir="dataset/processed/chapters/ISPAD-English-2022",
    chunks_dir="dataset/processed/chunks/ISPAD-English-2022",
    atoms_dir="dataset/processed/atoms/ISPAD-English-2022",
    metadata_dir="dataset/processed/metadata/ISPAD-English-2022",
    output_path="dataset/master/ISPAD-English-2022/master_corpus.jsonl",
    document_name="ISPAD_2022"
)
# Out:
# [INFO] Found 19 chapters
#
# [PROCESSING] Ch1-DefinitionEpidemiol
#
# [PROCESSING] Ch10PediatricDiabetes-2
#
# [PROCESSING] Ch11PediatricDiabetes
#
# [PROCESSING] Ch12-PediatricDiabetes
#
# [PROCESSING] Ch13PediatricDiabetes-2
#
# [PROCESSING] Ch14-PediatricDiabetes
#
# [PROCESSING] Ch15PediatricDiabetes-2
#
# [PROCESSING] Ch16-Technologyglucosem
#
# [PROCESSING] Ch17PediatricDiabetes-2
#
# [PROCESSING] ch21pediatricdiabetes
#
# [PROCESSING] Ch24-PediatricDiabetes
#
# [PROCESSING] Ch25-LimitedResourcesI
#
# [PROCESSING] ch2pediatricdiabetes-2
#
# [PROCESSING] Ch6-PediatricDiabetes
#
# [PROCESSING] Ch7PediatricDiabetes-2022
#
# [PROCESSING] Ch8-PediatricDiabetes
#
# [PROCESSING] Ch9-InsulinISPAD2022
#
# [PROCESSING] Chapt23PediatricDiabetes
#
# [PROCESSING] Chapter22PediatricDiabet
# [WARNING] Missing files for Chapter22PediatricDiabet
#
# ...
# [DONE] Normalized corpus saved
# [PATH] dataset\master\ISPAD-English-2022\master_corpus.jsonl
# [ROWS] 6771
#
# [STATS]
# L2 chunks: 1129
# ...
